# %%
import seaborn as sns
import pandas as pd
# import pandasql as ps
from pathlib import Path
from loguru import logger
import numpy as np
import warnings
import matplotlib.pyplot as plt
import json
import tomllib
# import duckdb
import re

from wa_analyzer.model import TextClustering

clustering = TextClustering()

warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# Load configuration and data
configfile = Path("../config.toml").resolve()
with configfile.open("rb") as f:
    config = tomllib.load(f)
datafile = (Path("..") / Path(config["processed"]) / config["current"]).resolve()
if not datafile.exists():
    logger.warning(
        "Datafile does not exist. First run src/preprocess.py, and check the timestamp!"
    )
wa_df = pd.read_parquet(datafile)

# %% [markdown]
# And now lets test it on the whatsapp data:

# %% [markdown]
# We know the authors, so let's use the labels.

# %%
# list unique authors
authors = list(np.unique(wa_df.author))
print(len(authors))
# Out:
# 78

# %%
def remove_url(text):
    return re.sub(r"^https?:\/\/.*[\r\n]*", "", text)

# %% [markdown]
# We take a subset of every author, and join their texts.
# Obviously, you can only do this if you know the authors, or at least the claimed authors. Concatenating all texts together will make the data useless.

# %%
# chunk size
# Each author’s text will be split into segments (“chunks”) of 500 characters.
n = 2500 # default = 500

# minimum number of parts to include author in corpus
min_parts = 4 # original =  2

# create corpus dictionary with author as key and list of text chunks as values
corpus = {}

for author in authors:

    # concatenate all messages from author into one long string
    subset = wa_df[wa_df.author == author].reset_index()
    # subset.shape

    # print number of messages per author
    print(f'Author {author} has {len(subset)} messages')
    
    # Concatenate all their messages into one long string
    longseq = " ".join(subset.message)
    print(f'Author {author} has {len(longseq)} message length characters')
    # print(f'{author}: {longseq}')

    # chunk everything into n-sized parts
    # Split that long text into fixed-size “chunks”
    parts = [longseq[i : i + n] for i in range(0, len(longseq), n)]
    print(f'Author {author} has {len(parts)} parts of size {n} characters pre-cleaning')

    # clean urls
    parts = [remove_url(chunk) for chunk in parts]
    # print(f'Author {author} has {len(parts)} parts of size {n} characters post-cleaning')
    # print(f'Author {author} has {len(longseq)} message length characters post-cleaning')

    # remove double spaces
    parts = [re.sub(" +", " ", chunk) for chunk in parts]
    # print(f'Author {author} has {len(parts)} parts of size {n} characters post-remove double spaces')
    print(f'Author {author} has {len(longseq)} message length characters post-remove double spaces')

    # keep only parts with more than min_parts
    if len(parts) > min_parts:
        corpus[author] = parts
corpus.keys()
# Out:
# Author bejeweled-beluga has 4 messages
# Author bejeweled-beluga has 978 message length characters
# Author bejeweled-beluga has 1 parts of size 2500 characters pre-cleaning
# Author bejeweled-beluga has 978 message length characters post-remove double spaces
# Author billowy-meerkat has 9 messages
# Author billowy-meerkat has 751 message length characters
# Author billowy-meerkat has 1 parts of size 2500 characters pre-cleaning
# Author billowy-meerkat has 751 message length characters post-remove double spaces
# Author bold-bison has 82 messages
# Author bold-bison has 5587 message length characters
# Author bold-bison has 3 parts of size 2500 characters pre-cleaning
# Author bold-bison has 5587 message length characters post-remove double spaces
# Author bouncy-worm has 35 messages
# Author bouncy-worm has 1506 message length characters
# Author bouncy-worm has 1 parts of size 2500 characters pre-cleaning
# Author bouncy-worm has 1506 message length characters post-remove double spaces
# Author cackling-eland has 106 messages
# Author cackling-eland has 13535 message length characters
# Author cackling-eland has 6 parts of size 2500 characters pre-cleaning
# Author cackling-eland has 13535 message length characters post-remove double spaces
# Author cackling-wasp has 3 messages
# Author cackling-wasp has 469 message length characters
# Author cackling-wasp has 1 parts of size 2500 characters pre-cleaning
# Author cackling-wasp has 469 message length characters post-remove double spaces
# Author captivating-dove has 16 messages
# Author captivating-dove has 1395 message length characters
# Author captivating-dove has 1 parts of size 2500 characters pre-cleaning
# Author captivating-dove has 1395 message length characters post-remove double spaces
# Author carefree-lark has 203 messages
# Author carefree-lark has 16174 message length characters
# Author carefree-lark has 7 parts of size 2500 characters pre-cleaning
# Author carefree-lark has 16174 message length characters post-remove double spaces
# Author cheerful-boar has 20 messages
# Author cheerful-boar has 2482 message length characters
# Author cheerful-boar has 1 parts of size 2500 characters pre-cleaning
# Author cheerful-boar has 2482 message length characters post-remove double spaces
# Author cheerful-mule has 173 messages
# Author cheerful-mule has 11282 message length characters
# Author cheerful-mule has 5 parts of size 2500 characters pre-cleaning
# Author cheerful-mule has 11282 message length characters post-remove double spaces
# Author chipper-quetzal has 4 messages
# Author chipper-quetzal has 321 message length characters
# Author chipper-quetzal has 1 parts of size 2500 characters pre-cleaning
# Author chipper-quetzal has 321 message length characters post-remove double spaces
# Author chuckling-stork has 12 messages
# Author chuckling-stork has 1129 message length characters
# Author chuckling-stork has 1 parts of size 2500 characters pre-cleaning
# Author chuckling-stork has 1129 message length characters post-remove double spaces
# Author coltish-owl has 21 messages
# Author coltish-owl has 2073 message length characters
# Author coltish-owl has 1 parts of size 2500 characters pre-cleaning
# Author coltish-owl has 2073 message length characters post-remove double spaces
# Author cordial-eel has 20 messages
# Author cordial-eel has 1966 message length characters
# Author cordial-eel has 1 parts of size 2500 characters pre-cleaning
# Author cordial-eel has 1966 message length characters post-remove double spaces
# Author coruscating-numbat has 1 messages
# Author coruscating-numbat has 40 message length characters
# Author coruscating-numbat has 1 parts of size 2500 characters pre-cleaning
# Author coruscating-numbat has 40 message length characters post-remove double spaces
# Author dazzling-curlew has 12 messages
# Author dazzling-curlew has 1281 message length characters
# Author dazzling-curlew has 1 parts of size 2500 characters pre-cleaning
# Author dazzling-curlew has 1281 message length characters post-remove double spaces
# Author dazzling-yak has 30 messages
# Author dazzling-yak has 2293 message length characters
# Author dazzling-yak has 1 parts of size 2500 characters pre-cleaning
# Author dazzling-yak has 2293 message length characters post-remove double spaces
# Author dynamic-frog has 20 messages
# Author dynamic-frog has 1304 message length characters
# Author dynamic-frog has 1 parts of size 2500 characters pre-cleaning
# Author dynamic-frog has 1304 message length characters post-remove double spaces
# Author ebullient-mosquito has 71 messages
# Author ebullient-mosquito has 3983 message length characters
# Author ebullient-mosquito has 2 parts of size 2500 characters pre-cleaning
# Author ebullient-mosquito has 3983 message length characters post-remove double spaces
# Author elaborate-jay has 11 messages
# Author elaborate-jay has 1312 message length characters
# Author elaborate-jay has 1 parts of size 2500 characters pre-cleaning
# Author elaborate-jay has 1312 message length characters post-remove double spaces
# Author entertaining-pig has 19 messages
# Author entertaining-pig has 3152 message length characters
# Author entertaining-pig has 2 parts of size 2500 characters pre-cleaning
# Author entertaining-pig has 3152 message length characters post-remove double spaces
# Author ethereal-lapwing has 49 messages
# Author ethereal-lapwing has 3951 message length characters
# Author ethereal-lapwing has 2 parts of size 2500 characters pre-cleaning
# Author ethereal-lapwing has 3951 message length characters post-remove double spaces
# Author eye-catching-hare has 151 messages
# Author eye-catching-hare has 16256 message length characters
# Author eye-catching-hare has 7 parts of size 2500 characters pre-cleaning
# Author eye-catching-hare has 16256 message length characters post-remove double spaces
# Author eye-catching-okapi has 24 messages
# Author eye-catching-okapi has 1961 message length characters
# Author eye-catching-okapi has 1 parts of size 2500 characters pre-cleaning
# Author eye-catching-okapi has 1961 message length characters post-remove double spaces
# Author flecked-beluga has 1 messages
# Author flecked-beluga has 25 message length characters
# Author flecked-beluga has 1 parts of size 2500 characters pre-cleaning
# Author flecked-beluga has 25 message length characters post-remove double spaces
# Author flecked-pheasant has 2 messages
# Author flecked-pheasant has 175 message length characters
# Author flecked-pheasant has 1 parts of size 2500 characters pre-cleaning
# Author flecked-pheasant has 175 message length characters post-remove double spaces
# Author flexible-platypus has 186 messages
# Author flexible-platypus has 10451 message length characters
# Author flexible-platypus has 5 parts of size 2500 characters pre-cleaning
# Author flexible-platypus has 10451 message length characters post-remove double spaces
# Author freckled-wolverine has 8 messages
# Author freckled-wolverine has 1099 message length characters
# Author freckled-wolverine has 1 parts of size 2500 characters pre-cleaning
# Author freckled-wolverine has 1099 message length characters post-remove double spaces
# Author funny-swallow has 21 messages
# Author funny-swallow has 1027 message length characters
# Author funny-swallow has 1 parts of size 2500 characters pre-cleaning
# Author funny-swallow has 1027 message length characters post-remove double spaces
# Author gaudy-whale has 4 messages
# Author gaudy-whale has 528 message length characters
# Author gaudy-whale has 1 parts of size 2500 characters pre-cleaning
# Author gaudy-whale has 528 message length characters post-remove double spaces
# Author giddy-tardigrade has 7 messages
# Author giddy-tardigrade has 330 message length characters
# Author giddy-tardigrade has 1 parts of size 2500 characters pre-cleaning
# Author giddy-tardigrade has 330 message length characters post-remove double spaces
# Author goofy-tiger has 24 messages
# Author goofy-tiger has 4232 message length characters
# Author goofy-tiger has 2 parts of size 2500 characters pre-cleaning
# Author goofy-tiger has 4232 message length characters post-remove double spaces
# Author happy-beaver has 41 messages
# Author happy-beaver has 6609 message length characters
# Author happy-beaver has 3 parts of size 2500 characters pre-cleaning
# Author happy-beaver has 6609 message length characters post-remove double spaces
# Author hilarious-dogfish has 12 messages
# Author hilarious-dogfish has 1396 message length characters
# Author hilarious-dogfish has 1 parts of size 2500 characters pre-cleaning
# Author hilarious-dogfish has 1396 message length characters post-remove double spaces
# Author hysterical-partridge has 1 messages
# Author hysterical-partridge has 23 message length characters
# Author hysterical-partridge has 1 parts of size 2500 characters pre-cleaning
# Author hysterical-partridge has 23 message length characters post-remove double spaces
# Author intense-toad has 782 messages
# Author intense-toad has 109954 message length characters
# Author intense-toad has 44 parts of size 2500 characters pre-cleaning
# Author intense-toad has 109954 message length characters post-remove double spaces
# Author joyful-okapi has 54 messages
# Author joyful-okapi has 4702 message length characters
# Author joyful-okapi has 2 parts of size 2500 characters pre-cleaning
# Author joyful-okapi has 4702 message length characters post-remove double spaces
# Author joyful-salmon has 6 messages
# Author joyful-salmon has 947 message length characters
# Author joyful-salmon has 1 parts of size 2500 characters pre-cleaning
# Author joyful-salmon has 947 message length characters post-remove double spaces
# Author kooky-tapir has 80 messages
# Author kooky-tapir has 5308 message length characters
# Author kooky-tapir has 3 parts of size 2500 characters pre-cleaning
# Author kooky-tapir has 5308 message length characters post-remove double spaces
# Author light-dunlin has 1 messages
# Author light-dunlin has 22 message length characters
# Author light-dunlin has 1 parts of size 2500 characters pre-cleaning
# Author light-dunlin has 22 message length characters post-remove double spaces
# Author limber-ostrich has 160 messages
# Author limber-ostrich has 9542 message length characters
# Author limber-ostrich has 4 parts of size 2500 characters pre-cleaning
# Author limber-ostrich has 9542 message length characters post-remove double spaces
# Author loony-albatross has 21 messages
# Author loony-albatross has 1410 message length characters
# Author loony-albatross has 1 parts of size 2500 characters pre-cleaning
# Author loony-albatross has 1410 message length characters post-remove double spaces
# Author lustrous-reindeer has 21 messages
# Author lustrous-reindeer has 1803 message length characters
# Author lustrous-reindeer has 1 parts of size 2500 characters pre-cleaning
# Author lustrous-reindeer has 1803 message length characters post-remove double spaces
# Author merry-salamander has 2 messages
# Author merry-salamander has 187 message length characters
# Author merry-salamander has 1 parts of size 2500 characters pre-cleaning
# Author merry-salamander has 187 message length characters post-remove double spaces
# Author mind-blowing-kudu has 45 messages
# Author mind-blowing-kudu has 3296 message length characters
# Author mind-blowing-kudu has 2 parts of size 2500 characters pre-cleaning
# Author mind-blowing-kudu has 3296 message length characters post-remove double spaces
# Author multicolored-dogfish has 9 messages
# Author multicolored-dogfish has 1183 message length characters
# Author multicolored-dogfish has 1 parts of size 2500 characters pre-cleaning
# Author multicolored-dogfish has 1183 message length characters post-remove double spaces
# Author nimble-raven has 6 messages
# Author nimble-raven has 288 message length characters
# Author nimble-raven has 1 parts of size 2500 characters pre-cleaning
# Author nimble-raven has 288 message length characters post-remove double spaces
# Author nutty-chamois has 5 messages
# Author nutty-chamois has 756 message length characters
# Author nutty-chamois has 1 parts of size 2500 characters pre-cleaning
# Author nutty-chamois has 756 message length characters post-remove double spaces
# Author peculiar-ape has 2 messages
# Author peculiar-ape has 97 message length characters
# Author peculiar-ape has 1 parts of size 2500 characters pre-cleaning
# Author peculiar-ape has 97 message length characters post-remove double spaces
# Author pellucid-quelea has 10 messages
# Author pellucid-quelea has 1431 message length characters
# Author pellucid-quelea has 1 parts of size 2500 characters pre-cleaning
# Author pellucid-quelea has 1431 message length characters post-remove double spaces
# Author peppy-badger has 17 messages
# Author peppy-badger has 960 message length characters
# Author peppy-badger has 1 parts of size 2500 characters pre-cleaning
# Author peppy-badger has 960 message length characters post-remove double spaces
# Author peppy-rat has 47 messages
# Author peppy-rat has 3239 message length characters
# Author peppy-rat has 2 parts of size 2500 characters pre-cleaning
# Author peppy-rat has 3239 message length characters post-remove double spaces
# Author piebald-jay has 11 messages
# Author piebald-jay has 815 message length characters
# Author piebald-jay has 1 parts of size 2500 characters pre-cleaning
# Author piebald-jay has 815 message length characters post-remove double spaces
# Author piebald-rhinoceros has 37 messages
# Author piebald-rhinoceros has 2263 message length characters
# Author piebald-rhinoceros has 1 parts of size 2500 characters pre-cleaning
# Author piebald-rhinoceros has 2263 message length characters post-remove double spaces
# Author psychedelic-boar has 12 messages
# Author psychedelic-boar has 755 message length characters
# Author psychedelic-boar has 1 parts of size 2500 characters pre-cleaning
# Author psychedelic-boar has 755 message length characters post-remove double spaces
# Author quick-chamois has 39 messages
# Author quick-chamois has 3143 message length characters
# Author quick-chamois has 2 parts of size 2500 characters pre-cleaning
# Author quick-chamois has 3143 message length characters post-remove double spaces
# Author radiant-coyote has 191 messages
# Author radiant-coyote has 18662 message length characters
# Author radiant-coyote has 8 parts of size 2500 characters pre-cleaning
# Author radiant-coyote has 18662 message length characters post-remove double spaces
# Author resplendent-aardwolf has 15 messages
# Author resplendent-aardwolf has 1820 message length characters
# Author resplendent-aardwolf has 1 parts of size 2500 characters pre-cleaning
# Author resplendent-aardwolf has 1820 message length characters post-remove double spaces
# Author riotous-wombat has 3 messages
# Author riotous-wombat has 243 message length characters
# Author riotous-wombat has 1 parts of size 2500 characters pre-cleaning
# Author riotous-wombat has 243 message length characters post-remove double spaces
# Author rollicking-ostrich has 60 messages
# Author rollicking-ostrich has 2680 message length characters
# Author rollicking-ostrich has 2 parts of size 2500 characters pre-cleaning
# Author rollicking-ostrich has 2680 message length characters post-remove double spaces
# Author saturated-whistling duck has 50 messages
# Author saturated-whistling duck has 3651 message length characters
# Author saturated-whistling duck has 2 parts of size 2500 characters pre-cleaning
# Author saturated-whistling duck has 3651 message length characters post-remove double spaces
# Author silky-lapwing has 185 messages
# Author silky-lapwing has 13937 message length characters
# Author silky-lapwing has 6 parts of size 2500 characters pre-cleaning
# Author silky-lapwing has 13937 message length characters post-remove double spaces
# Author snorting-ibex has 95 messages
# Author snorting-ibex has 11550 message length characters
# Author snorting-ibex has 5 parts of size 2500 characters pre-cleaning
# Author snorting-ibex has 11550 message length characters post-remove double spaces
# Author soft-eland has 59 messages
# Author soft-eland has 3992 message length characters
# Author soft-eland has 2 parts of size 2500 characters pre-cleaning
# Author soft-eland has 3992 message length characters post-remove double spaces
# Author sparkly-mole has 6 messages
# Author sparkly-mole has 398 message length characters
# Author sparkly-mole has 1 parts of size 2500 characters pre-cleaning
# Author sparkly-mole has 398 message length characters post-remove double spaces
# Author splattered-barracuda has 25 messages
# Author splattered-barracuda has 1829 message length characters
# Author splattered-barracuda has 1 parts of size 2500 characters pre-cleaning
# Author splattered-barracuda has 1829 message length characters post-remove double spaces
# Author springy-hare has 273 messages
# Author springy-hare has 28682 message length characters
# Author springy-hare has 12 parts of size 2500 characters pre-cleaning
# Author springy-hare has 28682 message length characters post-remove double spaces
# Author stippled-pig has 37 messages
# Author stippled-pig has 1373 message length characters
# Author stippled-pig has 1 parts of size 2500 characters pre-cleaning
# Author stippled-pig has 1373 message length characters post-remove double spaces
# Author sudsy-eland has 120 messages
# Author sudsy-eland has 7372 message length characters
# Author sudsy-eland has 3 parts of size 2500 characters pre-cleaning
# Author sudsy-eland has 7372 message length characters post-remove double spaces
# Author sudsy-gazelle has 7 messages
# Author sudsy-gazelle has 338 message length characters
# Author sudsy-gazelle has 1 parts of size 2500 characters pre-cleaning
# Author sudsy-gazelle has 338 message length characters post-remove double spaces
# Author sudsy-jellyfish has 195 messages
# Author sudsy-jellyfish has 16477 message length characters
# Author sudsy-jellyfish has 7 parts of size 2500 characters pre-cleaning
# Author sudsy-jellyfish has 16477 message length characters post-remove double spaces
# Author sunny-gazelle has 52 messages
# Author sunny-gazelle has 3478 message length characters
# Author sunny-gazelle has 2 parts of size 2500 characters pre-cleaning
# Author sunny-gazelle has 3478 message length characters post-remove double spaces
# Author tittering-fennec fox has 5 messages
# Author tittering-fennec fox has 321 message length characters
# Author tittering-fennec fox has 1 parts of size 2500 characters pre-cleaning
# Author tittering-fennec fox has 321 message length characters post-remove double spaces
# Author upbeat-pigeon has 21 messages
# Author upbeat-pigeon has 1888 message length characters
# Author upbeat-pigeon has 1 parts of size 2500 characters pre-cleaning
# Author upbeat-pigeon has 1888 message length characters post-remove double spaces
# Author vivid-rhinoceros has 236 messages
# Author vivid-rhinoceros has 29170 message length characters
# Author vivid-rhinoceros has 12 parts of size 2500 characters pre-cleaning
# Author vivid-rhinoceros has 29170 message length characters post-remove double spaces
# Author waggish-porcupine has 34 messages
# Author waggish-porcupine has 3654 message length characters
# Author waggish-porcupine has 2 parts of size 2500 characters pre-cleaning
# Author waggish-porcupine has 3654 message length characters post-remove double spaces
# Author wispy-reindeer has 18 messages
# Author wispy-reindeer has 1010 message length characters
# Author wispy-reindeer has 1 parts of size 2500 characters pre-cleaning
# Author wispy-reindeer has 1010 message length characters post-remove double spaces
# Author zany-trout has 108 messages
# Author zany-trout has 11032 message length characters
# Author zany-trout has 5 parts of size 2500 characters pre-cleaning
# Author zany-trout has 11032 message length characters post-remove double spaces
# dict_keys(['cackling-eland', 'carefree-lark', 'cheerful-mule', 'eye-catching-hare', 'flexible-platypus', 'intense-toad', 'radiant-coyote', 'silky-lapwing', 'snorting-ibex', 'springy-hare', 'sudsy-jellyfish', 'vivid-rhinoceros', 'zany-trout'])

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

# create document-term matrix with 3-grams
# Create the vectorizer
# Use character-level 3-grams (sequences of 3 characters)
# Analyze text at the character level (not by words).
# Extract character trigrams (sequences of 3 consecutive characters).
# The vectorizer will treat each unique 3-character sequence as a feature (a column in the final matrix).

"""
"text" → trigrams: "tex", "ext"
"banana" → trigrams: "ban", "ana", "nan", "ana"
"""

vectorizer = CountVectorizer(analyzer="char", ngram_range=(3, 3))

# Fit and transform the text chunks
# Combine all text chunks from all authors into a single list
"""
parts is a list of text chunks, e.g.:
["text", "banana"], in our case string chunks of 500 characters!

.fit_transform() does two things:
1. fit — finds all unique trigrams across all chunks (builds the vocabulary).
2. transform — counts how many times each trigram appears in each chunk.

"""

X = vectorizer.fit_transform(parts)

# Convert the sparse matrix to a dense format (if needed)
# Note: This can be memory-intensive for large datasets
X = np.asarray(X.todense())

X.shape # (number of text chunks, number of unique 3-grams) / (23, 2028)
# Out:
# (5, 2030)

# %%
import matplotlib.pyplot as plt

text = [part for text in corpus.values() for part in text]
wa_labels = [k for k, v in corpus.items() for _ in range(len(v))]
# we set batch to false, because we already batched the data
# clustering(text=text, k=100, labels=wa_labels, batch=False, method="tSNE")
clustering(text=text, k=100, labels=wa_labels, batch=False, method="PCA")

plt.legend(title="Author", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xticks([])
plt.yticks([])
plt.title("Distinct authors in the WhatsApp dataset")
# Out:
# 2025-10-14 21:09:36.915 | INFO     | wa_analyzer.model:fit:35 - Vectorized text into shape (129, 11657)
# 2025-10-14 21:09:37.069 | INFO     | wa_analyzer.model:reduce_dims:42 - Using PCA
# Text(0.5, 1.0, 'Distinct authors in the WhatsApp dataset')

# %% [markdown]
# PCA visualization of WhatsApp messages from the apartment building looks great.
#
# 🧠 What the analysis does
#
# You used character-level trigram PCA to analyze writing patterns across WhatsApp messages from multiple residents in your building.
#
# Each point = one chunk of messages (about 500 characters).
#
# Each color = a different author.
#
# PCA reduces thousands of text features (character trigrams) into two principal components, which capture the largest stylistic variation.
#
# So, the plot visualizes differences in writing style between authors.

# %% [markdown]
# 📊 What your plot shows
#
# Dense cluster in the center
#
# Most messages overlap heavily in the middle.
#
# Indicates that many residents write in similar styles — short, conversational WhatsApp language (abbreviations, emojis, informal tone) creates little stylistic separation.
#
# A few outliers spread around the edges
#
# These could represent:
#
# Residents with distinctive writing habits (longer sentences, punctuation, formal tone, etc.).
#
# People who write in another language or mix in different scripts.
#
# Outlier chunks with very short or very long messages, or a high density of emojis, URLs, or special characters.
#
# No clear, tight clusters per author
#
# Suggests that PCA alone doesn’t fully separate authors — which is expected for short, casual text.
#
# Writing variation within one person may be larger than variation between people in WhatsApp chats.
